# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# u'0.23.4'

# %% [markdown]
# ## Loading other data files

# %%
bike=pd.read_csv("bikeSharing.csv")
bike.head()
# Out:
#         datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  1/1/2011 0:00       1        0           0        1  9.84  14.395
# 1  1/1/2011 1:00       1        0           0        1  9.02  13.635
# 2  1/1/2011 2:00       1        0           0        1  9.02  13.635
# 3  1/1/2011 3:00       1        0           0        1  9.84  14.395
# 4  1/1/2011 4:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %% [markdown]
# ## Examining Data

# %%
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
# datetime      10886 non-null object
# season        10886 non-null int64
# holiday       10886 non-null int64
# workingday    10886 non-null int64
# weather       10886 non-null int64
# temp          10886 non-null float64
# atemp         10886 non-null float64
# humidity      10886 non-null int64
# windspeed     10886 non-null float64
# casual        10886 non-null int64
# registered    10886 non-null int64
# count         10886 non-null int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.6+ KB

# %%
bike.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# std        8.474601     19.245033      8.164537     49.960477    151.039033
# min        0.760000      0.000000      0.000000      0.000000      0.000000
# 25%       16.665000     47.000000      7.001500      4.000000     36.000000
# 50%       24.240000     62.000000     12.998000     17.000000    118.000000
# 75%       31.060000     77.000000     16.997900     49.000000    222.000000
# max       45.455000    100.000000     56.996900    367.000000    886.000000
#
#               count
# count  10886.000000
# mean     191.574132
# std      181.144454
# min        1.000000
# 25%       42.000000
# 50%      145.000000
# 75%      284.000000
# max      977.000000

# %% [markdown]
# ## Handling NULL Values

# %% [markdown]
# ## Correlation

# %%
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
# datetime      10886 non-null object
# season        10886 non-null int64
# holiday       10886 non-null int64
# workingday    10886 non-null int64
# weather       10886 non-null int64
# temp          10886 non-null float64
# atemp         10886 non-null float64
# humidity      10886 non-null int64
# windspeed     10886 non-null float64
# casual        10886 non-null int64
# registered    10886 non-null int64
# count         10886 non-null int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.6+ KB

# %%
correlation=bike.corr()
correlation
# Out:
#               season   holiday  workingday   weather      temp     atemp  \
# season      1.000000  0.029368   -0.008126  0.008879  0.258689  0.264744
# holiday     0.029368  1.000000   -0.250491 -0.007074  0.000295 -0.005215
# workingday -0.008126 -0.250491    1.000000  0.033772  0.029966  0.024660
# weather     0.008879 -0.007074    0.033772  1.000000 -0.055035 -0.055376
# temp        0.258689  0.000295    0.029966 -0.055035  1.000000  0.984948
# atemp       0.264744 -0.005215    0.024660 -0.055376  0.984948  1.000000
# humidity    0.190610  0.001929   -0.010880  0.406244 -0.064949 -0.043536
# windspeed  -0.147121  0.008409    0.013373  0.007261 -0.017852 -0.057473
# casual      0.096758  0.043799   -0.319111 -0.135918  0.467097  0.462067
# registered  0.164011 -0.020956    0.119460 -0.109340  0.318571  0.314635
# count       0.163439 -0.005393    0.011594 -0.128655  0.394454  0.389784
#
#             humidity  windspeed    casual  registered     count
# season      0.190610  -0.147121  0.096758    0.164011  0.163439
# holiday     0.001929   0.008409  0.043799   -0.020956 -0.005393
# workingday -0.010880   0.013373 -0.319111    0.119460  0.011594
# weather     0.406244   0.007261 -0.135918   -0.109340 -0.128655
# temp       -0.064949  -0.017852  0.467097    0.318571  0.394454
# atemp      -0.043536  -0.057473  0.462067    0.314635  0.389784
# humidity    1.000000  -0.318607 -0.348187   -0.265458 -0.317371
# windspeed  -0.318607   1.000000  0.092276    0.091052  0.101369
# casual     -0.348187   0.092276  1.000000    0.497250  0.690414
# registered -0.265458   0.091052  0.497250    1.000000  0.970948
# count      -0.317371   0.101369  0.690414    0.970948  1.000000

# %%
correlation['count']
# Out:
# season        0.163439
# holiday      -0.005393
# workingday    0.011594
# weather      -0.128655
# temp          0.394454
# atemp         0.389784
# humidity     -0.317371
# windspeed     0.101369
# casual        0.690414
# registered    0.970948
# count         1.000000
# Name: count, dtype: float64

# %%
import seaborn as sns
sns.__version__
#0.9.0#
# Out:
# '0.9.0'

# %%
sns.heatmap(bike.corr())

# %%
sns.heatmap(bike.corr(),cmap='YlGnBu',annot=True)

# %%
from matplotlib import pyplot

a4_dims = (11.7, 8.27)
fig, ax = pyplot.subplots(figsize=a4_dims)
sns.heatmap(ax=ax,data=bike.corr(),cmap='YlGnBu',annot=True)

# %%
# %matplotlib inline

# %%
sns.barplot(data=bike,x='workingday',y='count')

# %%
correlation=bike.corr()
correlation['count']
# Out:
# season        0.163439
# holiday      -0.005393
# workingday    0.011594
# weather      -0.128655
# temp          0.394454
# atemp         0.389784
# humidity     -0.317371
# windspeed     0.101369
# casual        0.690414
# registered    0.970948
# count         1.000000
# Name: count, dtype: float64

# %%
correlation=np.abs(correlation['count'])
correlation
# Out:
# season        0.163439
# holiday       0.005393
# workingday    0.011594
# weather       0.128655
# temp          0.394454
# atemp         0.389784
# humidity      0.317371
# windspeed     0.101369
# casual        0.690414
# registered    0.970948
# count         1.000000
# Name: count, dtype: float64

# %%
correlation.sort_values(inplace=True)
correlation
# Out:
# holiday       0.005393
# workingday    0.011594
# windspeed     0.101369
# weather       0.128655
# season        0.163439
# humidity      0.317371
# atemp         0.389784
# temp          0.394454
# casual        0.690414
# registered    0.970948
# count         1.000000
# Name: count, dtype: float64

# %%
tobeRemoved=correlation[correlation<0.3]
tobeRemoved
# Out:
# holiday       0.005393
# workingday    0.011594
# windspeed     0.101369
# weather       0.128655
# season        0.163439
# Name: count, dtype: float64

# %%
bikeFS=bike.drop(tobeRemoved.index,axis=1)
bikeFS.head()
# Out:
#               datetime  temp   atemp  humidity  casual  registered  count
# 0  2011-01-01 00:00:00  9.84  14.395        81       3          13     16
# 1  2011-01-01 01:00:00  9.02  13.635        80       8          32     40
# 2  2011-01-01 02:00:00  9.02  13.635        80       5          27     32
# 3  2011-01-01 03:00:00  9.84  14.395        75       3          10     13
# 4  2011-01-01 04:00:00  9.84  14.395        75       0           1      1

# %% [markdown]
# ## Encoding

# %%
from sklearn.preprocessing import OneHotEncoder
import sklearn
sklearn.__version__
#0.20.0#
# Out:
# '0.20.1'

# %%
enc.categories_
# Out:
# [array(['00001', '00002', '00003', '00004', '00005', '00006', '00007',
#         '00008', '00009', '0000A', '0000B', '0000C', '0000D', '0000E',
#         '0000F', '00010', '00011', '00012', '00013', '00014', '00015',
#         '00016', '00017', '00018', '00019', '0001A', '0001B', '0001C',
#         '0001D', '0001E', '0001F', '00020', '00021', '00022', '00023',
#         '00024', '00025', '00026', '00027', '00028', '00029', '0002A',
#         '0002B', '0002C', '0002D', '0002E', '0002F', '00030', '00031',
#         '00032', '00033', '00034', '00035', '00036', '00037', '00038',
#         '00039', '0003A', '0003B', '0003C', '0003D', '0003E', '0003F',
#         '00040', '00041', '00042', '00043', '00044', '00045', '00046',
#         '00047', '00048', '00049', '0004A', '0004B', '0004C', '0004D',
#         '0004E', '0004F', '00050', '00051', '00052', '00053', '00054',
#         '00055', '00056', '00057', '00058', '00059', '0005A', '0005B',
#         '0005C', '0005D', '0005E', '0005F', '00060', '00061', '00062',
#         '00063', '00064', '00065', '00066', '00067', '00068', '00069',
#         '0006A', '0006B', '0006C', '0006D', '0006E', '0006F', '00070',
#         '00071', '00072', '00073', '00074', '00075', '00076', '00077',
#         '00078', '00079', '0007A', '0007B', '0007C', '0007D', '0007E',
#         '0007F', '00080', '00081', '00082', '00083', '00084', '00085',
#         '00086', '00087', '00088', '00089', '0008A', '0008B', '0008C',
#         '0008D', '0008E', '0008F', '00090', '00091', '00092', '00093',
#         '00094', '00095', '00096', '00097', '00098', '00099', '0009A',
#         '0009B', '0009C', '0009D', '0009E', '0009F', '000A0', '000A1',
#         '000A2', '000A3', '000A4', '000A5', '000A6', '000A7', '000A8',
#         '000A9', '000AA', '000AB', '000AC', '000AD', '000AE', '000AF',
#         '000B0', '000B1', '000B2', '000B3', '000B4', '000B5', '000B6',
#         '000B7', '000B8', '000B9', '000BA', '000BB', '000BC', '000BD',
#         '000BE', '000BF', '000C0', '000C1', '000C2', '000C3', '000C4',
#         '000C5', '000C6', '000C7', '000C8', '000C9', '000CA', '000CB',
#         '000CC', '000CD', '000CE', '000CF', '000D0', '000D1', '000D2',
#         '000D3', '000D4', '000D5', '000D6', '000D7', '000D8', '000D9',
#         '000DA', '000DB', '000DC', '000DD', '000DE', '000DF', '000E0',
#         '000E1', '000E2', '000E3', '000E4', '000E5', '000E6', '000E7',
#         '000E8', '000E9', '000EA', '000EB', '000EC', '000ED', '000EE',
#         '000EF', '000F0', '000F1', '000F2', '000F3', '000F4', '000F5',
#         '000F6', '000F7', '000F8', '000F9', '000FA', '000FB', '000FC',
#         '000FD', '000FE', '000FF', '00100', '00101', '00102', '00103',
#         '00104', '00105', '00106', '00107', '00108', '00109', '0010A',
#         '0010B', '0010C', '0010D', '0010E', '0010F', '00110', '00111',
#         '00112', '00113', '00114', '00115', '00116', '00117', '00118',
#         '00119', '0011A', '0011B', '0011C', '0011D', '0011E', '0011F',
#         '00120', '00121', '00122', '00123', '00124', '00125', '00126',
#         '00127', '00128', '00129', '0012A', '0012B', '0012C', '0012D',
#         '0012E', '0012F', '00130', '00131', '00132', '00133', '00134',
#         '00135', '00136', '00137', '00138', '00139', '0013A', '0013B',
#         '0013C', '0013D', '0013E', '0013F', '00140', '00141', '00142',
#         '00143', '00144', '00145', '00146', '00147', '00148', '00149',
#         '0014A', '0014B', '0014C', '0014D', '0014E', '0014F', '00150',
#         '00151', '00152', '00153', '00154', '00155', '00156', '00157',
#         '00158', '00159', '0015A', '0015B', '0015C', '0015D', '0015E',
#         '0015F', '00160', '00161', '00162', '00163', '00164', '00165',
#         '00166', '00167', '00168', '00169', '0016A', '0016B', '0016C',
#         '0016D', '0016E', '0016F', '00170', '00171', '00172', '00173',
#         '00174', '00175', '00176', '00177', '00178', '00179', '0017A',
#         '0017B', '0017C', '0017D', '0017E', '0017F', '00180', '00181',
#         '00182', '00183', '00184', '00185', '00186', '00187', '00188',
#         '00189', '0018A', '0018B', '0018C', '0018D', '0018E', '0018F',
#         '00190', '00191', '00192', '00193', '00194', '00195', '00196',
#         '00197', '00198', '00199', '0019A', '0019B', '0019C', '0019D',
#         '0019E', '0019F', '001A0', '001A1', '001A2', '001A3', '001A4',
#         '001A5', '001A6', '001A7', '001A8', '001A9', '001AA', '001AB',
#         '001AC', '001AD', '001AE', '001AF', '001B0', '001B1', '001B2',
#         '001B3', '001B4', '001B5', '001B6', '001B7', '001B8', '001B9',
#         '001BA', '001BB', '001BC', '001BD', '001BE', '001BF', '001C0',
#         '001C1', '001C2', '001C3', '001C4', '001C5', '001C6', '001C7',
#         '001C8', '001C9', '001CA', '001CB', '001CC', '001CD', '001CE',
#         '001CF', '001D0', '001D1', '001D2', '001D3', '001D4', '001D5',
#         '001D6', '001D7', '001D8', '001D9', '001DA', '001DB', '001DC',
#         '001DD', '001DE', '001DF', '001E0', '001E1', '001E2', '001E3',
#         '001E4', '001E5', '001E6', '001E7', '001E8', '001E9', '001EA',
#         '001EB', '001EC', '001ED', '001EE', '001EF', '001F0', '001F1',
#         '001F2', '001F3', '001F4', '001F5', '001F6', '001F7', '001F8',
#         '001F9', '001FA', '001FB', '001FC', '001FD', '001FE', '001FF',
#         '00200', '00201', '00202', '00203', '00204', '00205', '00206',
#         '00207', '00208', '00209', '0020A', '0020B', '0020C', '0020D',
#         '0020E', '0020F', '00210', '00211', '00212', '00213', '00214',
#         '00215', '00216', '00217', '00218', '00219', '0021A', '0021B',
#         '0021C', '0021D', '0021E', '0021F', '00220', '00221', '00222',
#         '00223', '00224', '00225', '00226', '00227', '00228', '00229',
#         '0022A', '0022B', '0022C', '0022D', '0022E', '0022F', '00230',
#         '00231', '00232', '00233', '00234', '00235', '00236', '00237',
#         '00238', '00239', '0023A', '0023B', '0023C', '0023D', '0023E',
#         '0023F', '00240', '00241', '00242', '00243', '00244', '00245',
#         '00246', '00247', '00248', '00249', '0024A', '0024B', '0024C',
#         '0024D', '0024E', '0024F', '00250', '00251', '00252', '00253',
#         '00254', '00255', '00256', '00257', '00258', '00259', '0025A',
#         '0025B', '0025C', '0025D', '0025E', '0025F', '00260'], dtype=object),
#  array(['2Knk1KF', '5QKIjwyXr4MCZTEp7uAkS8PtBLcn', 'AERks4l',
#         'ByQdnLRlFnny2k4AJzG', 'Fveq5yuDUj6drSMiZO3mXe', 'JXVE',
#         'LrdVolaSGUfkVeWC', 'LrdZy8QqgUfkVShG', 'ND3t9Yro9U', 'NRCqczK',
#         'RO12', 'TW8dXluYzKpktZjuY8kSPBaZa', '_7J0OGNN8s6gFzbM',
#         'e6CkoqApVR', 'eSGpMwS8zSGgq_trOpckZ5', 'g62hiBSaKg',
#         'onTuEhrJJQy_H3IHkZku5AFczhYGqxJ890',
#         'qqimvRzsp8ZZdKRPgzLg68joSn_k', 'rEUOq2QD1qfkRr6qpua',
#         'snf9xe6PBwBZ8lKzhEz', 'ues7INAmyjdS1vDd0YL9jU', 'vuPfq6YcbX',
#         'w9ygS99Qp_', 'zPhCMhkz9XiOF7LgT9VfJZ3yI'], dtype=object),
#  array(['ArtjQZmIvr94p', 'CiJDdr4TQ0rGERIS', 'LfvqpCtLOY', 'ev6I', 'taul'],
#        dtype=object),
#  array(['1K8T', 'z3mO'], dtype=object),
#  array(['0LaQ', '0WHw', '0Xwj', '0Y9G', '0YIT', '0aHy', '0kpG', '12fX',
#         '19FS', '1TqK', '2Ix5', '42Cy', '487l', '4JaS', '4fje', '72yt',
#         '7ALb', '7M9D', '7gSz', '7wJ6', '80HR', '8qEx', 'AHgj', 'AKN1',
#         'AnrR', 'Bxva', 'ChAX', 'EJC9', 'EzKK', 'F9g8', 'FPxv', 'FgS1',
#         'G6s_', 'GYbZ', 'HR69', 'IGdn', 'IvdZ', 'JLbT', 'KqYs', 'L80O',
#         'LFM_', 'LLPZ', 'LZs_', 'L_LK', 'LloI', 'NF63', 'NHzE', 'NSDI',
#         'NbV4', 'OTVu', 'OY2L', 'P9et', 'PGNs', 'PJLW', 'PbOJ', 'QQSE',
#         'R4_H', 'SzjZ', 'TIPl', 'TLkP', 'TyGl', 'USOt', 'Uk76', 'UkfA',
#         'W5sH', 'WkTj', 'Wmd1', 'X94c', 'X9_k', 'Xa_z', 'Y2P0', 'YFAj',
#         'YPhp', 'YVv3', 'YmZp', 'ZF5Q', 'ZHNR', 'ZSv9', '_8YK', '_Clr',
#         'aD1X', 'c9jp', 'dTod', 'dWQK', 'dm89', 'ffXs', 'g6No', 'h3JW',
#         'hAOr', 'hM6W', 'j1T2', 'kNzO', 'kwI9', 'lK27', 'mAW3', 'nCqp',
#         'nQZ6', 'oXaB', 'pE9z', 'pGTb', 'pdks', 'rXTS', 'sKnY', 'sbZD',
#         'sj_R', 'ssAy', 'tXti', 'tzKK', 'uErj', 'uNkU', 'ujBx', 'vSNn',
#         'vsvk', 'wGW5', 'wOc1', 'xgSF', 'yMvB', 'yYar', 'z32l'],
#        dtype=object),
#  array(['06Xs45W', '0BLnYyd', '0Cp8pHi', '0Vr7wZ4', '0kyQIhb', '0nY9OFL',
#         '0qCl1hh', '0v27GMk', '1qnne2L', '1ucARMl', '1ucchDb', '25Ax0bI',
#         '2a37BoT', '2cB4lx4', '2cBJEvB', '2cBvY8M', '2dLzqEA', '2gN7C3_',
#         '2gN8HPr', '2gNd3iM', '31DqtNX', '3FCrXBz', '3ZjbFkF', '3cunsla',
#         '3d6Ybuk', '3d6d0DS', '3fI4jEC', '3n6biah', '4JEMGuV', '4e311pK',
#         '4jFcSKu', '4rXn9NE', '5EpXqGp', '5HUJ34g', '5Q3Ofm0', '5UkZJEa',
#         '60sCyD5', '6CXYbuk', '6F5nnDZ', '6JEJgAs', '6KF0k8W', '6LkJ26Z',
#         '6SycSKu', '6Wu7zLh', '6X_nFi6', '6oGKKVi', '6oGvcTJ', '6zFO4aK',
#         '77fJ9iC', '7GUAEa8', '7Kf6gtF', '7UBxJVj', '7c9SNLr', '7kAl2XU',
#         '7nPy3El', '7z8V8VT', '83iWKYv', '85iypzx', '86dToXU', '88mV8VT',
#         '8DBOkab', '8NsJSJw', '8Nsn57c', '8Nsx4QS', '8ij6Lg8', '92zmJ1u',
#         '9GJGgoz', '9GJxoic', 'A4fCIek', 'AAScNhj', 'AIO9x15', 'B5n4Lhq',
#         'B5nc5gJ', 'BBmwWHr', 'Bnu7wlP', 'ClIoukx', 'ClIuMXJ', 'DP5xtq0',
#         'DVqAQJk', 'EKR938I', 'EQsMhNR', 'EnSNXZR', 'F0CcSKu', 'F0DSdMg',
#         'FJD_9E2', 'FJDupBg', 'FSVXtaU', 'FcmhANo', 'FjnupBg', 'Fn0AVx0',
#         'G2zwXf5', 'G6aMVop', 'GLcYYlr', 'GOBtJoj', 'GRl7qwL', 'GSG4ewH',
#         'GUg04mC', 'GUgwv86', 'GdzFZs5', 'GjukJwu', 'H5Q_VBs', 'H7_heVi',
#         'H8V_L_f', 'H9Tg2A0', 'HPUGayG', 'HQZpiVB', 'IMI3Naj', 'IoVCPws',
#         'J7Knr2P', 'J7Kx0bI', 'JAVLmBg', 'JVFLDAi', 'JZmRiq8', 'K6McVcA',
#         'K8Lod6b', 'Kn7o7aV', 'Kn7uqyB', 'KweCreM', 'L7tEXGF', 'LFKACyb',
#         'LFsq5o9', 'LG0JHBC', 'LJS7NLP', 'LJSqkpJ', 'LK5nVRA', 'LcOyQy1',
#         'LnrdQSP', 'LnrlJRo', 'M0FFFda', 'M8_d0DS', 'MErO9Nm', 'MNw47cQ',
#         'MPSMkpB', 'Mbu95gF', 'Ml6kiFp', 'Mqs4NQF', 'MqsJzp5', 'Mqscy5d',
#         'MvUxJVj', 'My6jZUX', 'N455JqQ', 'NldASpP', 'NwKnsla', 'Nxdw8DQ',
#         'OHMwWsw', 'OKQ4Lhq', 'ON5Ou9e', 'OnikTQ1', 'PFW3ud5', 'PHNvXy8',
#         'Po5g339', 'PvuPLzH', 'PyeGayG', 'Q9Rq8UC', 'R4C9W2K', 'RPKu5tB',
#         'RZHR5DT', 'RxDMhNR', 'SDw7JO2', 'SY4EQZQ', 'SY4VCna', 'SkI4ewH',
#         'SmU9OFL', 'SmUcc4J', 'SqbCPGE', 'T2e7I6V', 'T7ckueW', 'TSdlkJq',
#         'TgqARMl', 'TsqM639', 'TwRo8uU', 'UGl8_3u', 'V8V_q1V', 'VWnXzAw',
#         'VWnxM5B', 'VcW4jEC', 'VjLN8e1', 'VjLkKKt', 'WI7JJYr', 'WIUdTJr',
#         'WkH7nZN', 'WkHCdxD', 'WkHrLeh', 'WlFnZSn', 'WtcJHBC', 'Wtcc5gJ',
#         'X2G4NDc', 'XX34iqB', 'XX3cFZv', 'XaPdR0M', 'XktPwWy', 'Xlthli9',
#         'XvJ7pE3', 'Y6hYfcf', 'YLTY4q6', 'YLToWha', 'Z4ho8ot', 'ZBORawV',
#         'ZEF5V1L', 'ZTQCNUi', 'ZtBNj4_', 'ZtMq7Fq', 'ZvGeml7', '_A3J26Z',
#         '_A3lbGp', '_A3nXHo', '_gMXOhW', '_gMxSlj', '_t7Mbg2', '_ybO0dd',
#         '_ybzqEA', 'a5zFpID', 'aKBg0iR', 'aKBrLEy', 'aWx9MxI', 'abRsKl9',
#         'af1vEdV', 'apKK0yW', 'aqcp_2L', 'au1K0yW', 'au1nqNs', 'au1viRg',
#         'b2zTeOI', 'bV9grxB', 'bbm5wbm', 'bvZcCja', 'cGZJt03', 'cGZPV0c',
#         'cJKrSMY', 'cJKwkuM', 'cMjcTxR', 'ckoh3aP', 'cmPXOhW', 'creCyD5',
#         'creg0bq', 'cwyCreM', 'dRqabdC', 'dpLnqNs', 'eDdnaaX', 'eYPJuq4',
#         'esxkA1P', 'f2Cr1U6', 'fIZ2EMp', 'fLzAmkt', 'fVhJr0F', 'f_onF0C',
#         'fayYfhR', 'fhk21Ss', 'fi0tdX8', 'fqeOwLG', 'fqedTJr', 'fqel91c',
#         'gNIaOJ7', 'gNIgCYR', 'gRinF0C', 'gRirkF8', 'gmq88LT', 'gwY4NQF',
#         'hHJdCrr', 'hWDloaA', 'hWvno_n', 'ho_bxgw', 'ho_dR0M', 'iJzviRg',
#         'iYI85Wp', 'innSmtm', 'innngaa', 'innxbJ3', 'j5_Xk4l', 'j9nq_S5',
#         'jCeGyn_', 'jJ_PTZq', 'jJ_lbGp', 'jJ_nXHo', 'jMFN0hm', 'jMFkXPi',
#         'jX5lhSa', 'jZ0kHY6', 'jZGp_0J', 'jfP4Shd', 'jfPn1fB', 'jlzcpQc',
#         'jvoyZxp', 'jwhtMxl', 'kH3c06V', 'kJ14Htb', 'kJ1ERUT', 'kLfBUCv',
#         'kO1abdC', 'ka3eV8O', 'ka_ns41', 'kjvBmIU', 'kkNNXZR', 'knVbxgw',
#         'kozdzR5', 'ks5A1LJ', 'l1Yysxi', 'lCpd8Q3', 'lKNMukw', 'm4ZnXKj',
#         'm64YMHN', 'mLYOTMK', 'mMEMUDL', 'mR_k2Zj', 'mTdXsZV', 'mfjcTEF',
#         'mhknt93', 'mjAngaa', 'ml5cNhj', 'n0UnRzy', 'n0tQn2A', 'nFmFZs5',
#         'nLJ0ibt', 'nmm4k19', 'oKsnV1D', 'oKsne2L', 'oWeheVi', 'ofiZR7x',
#         'ojHnF0C', 'p2oeZ9L', 'pKHV6tQ', 'pKIL3j7', 'pro8v8X', 'q5Zs43J',
#         'q6YpzLh', 'qEKLIo1', 'qEdASpP', 'qMlD1gf', 'qNenhjK', 'qQKVp7s',
#         'qWBguYp', 'qbzaVTy', 'qbzg2A0', 'qsgYDSI', 'r34vTzP', 'r6c4NQF',
#         'r6ccy5d', 'r6ox19i', 'rPAXbNT', 'rRoCfXI', 'rRx7ehn', 'rXH4Eny',
#         'rXHcNhj', 'rpAtFlZ', 'ryQJDqx', 'sGhnkcQ', 'sjdgCVv', 't0l7C3_',
#         't6TtIjH', 'tKnrLEy', 'tUuJwlU', 'tUuP5QB', 't_S7E9Z', 'u6iViyY',
#         'uMA4Shd', 'ugG1tiY', 'uqsq_S5', 'vHHY4q6', 'vL0nV76', 'vL0xuYM',
#         'vQ_JaGu', 'vfNGyn_', 'vfNVrZR', 'voX4XxH', 'w9kwuGt', 'wLsMvt2',
#         'wjUyWhJ', 'wnPbPon', 'wrRuXRS', 'x44vEdV', 'x8bPoJV', 'x8bu1hQ',
#         'xRePyOH', 'xReuqyB', 'xUTqnbN', 'xziuXRS', 'z8FO0dd', 'zN9Vdmm',
#         'zg_pBTu', 'zmMlkJq'], dtype=object),
#  array(['9_Y1', 'F3hy', 'HLqf', 'dgxZ'], dtype=object),
#  array(['000J', '0A_v', '15m3', '1Bp0', '3NyY', '47ra', '4N0K', '4nnx',
#         '5euo', '6Kw9', '6TCl', '7JiV', '7WNq', '7pVf', '8BBI', 'AKLO',
#         'Albh', 'Bw19', 'C6Eu', 'C7DI', 'Cgc3', 'DFSe', 'DmlN', 'DtNL',
#         'EKFb', 'Ew1Q', 'EwzD', 'F_Lu', 'FbIm', 'Gx0B', 'H1uM', 'H9GL',
#         'ID5l', 'KfYH', 'KubS', 'LqKm', 'MBhA', 'MGOA', 'NFMt', 'Nbbb',
#         'Px52', 'QBpP', 'QMes', 'RVjC', 'RcM7', 'STGZ', 'SkZj', 'TFSW',
#         'TjV7', 'VILw', 'VwCR', 'WGOH', 'X8zP', 'Y9Bl', 'YBFS', 'YGOC',
#         'YULl', 'YePk', 'Z5OU', 'ZKJc', 'Zazx', '_48V', '_r21', '_xpN',
#         'c2JP', 'cyKH', 'e7QV', 'eQTr', 'em8I', 'f4dr', 'fTh6', 'gnEy',
#         'iVbl', 'jakt', 'jdbz', 'k13i', 'kJJ7', 'lXxA', 'm7JR', 'mTeA',
#         'm_h1', 'nr0d', 'pQsY', 'qaiO', 'rGJy', 'rzbc', 't_4G', 'vm5R',
#         'vzJD', 'wGwL', 'xQ2A', 'xSqs', 'yrDU', 'z5Ry', 'zfpA'],
#        dtype=object),
#  array(['15TtzZrRt2', '6C53VA1kCv', '7M47J5GA0pTYIFxg5uy',
#         'DHn_WUyBhW_whjA88g9bvA64_', 'GjJ35utlTa_GNSvxxpb9ju', 'Kxdu',
#         'NKv3VA1BpP', 'me75fM6ugJ'], dtype=object),
#  array(['kIsH', 'sBgB'], dtype=object),
#  array(['3av_', '7A3j', 'g5HH', 'oT7d', 'uKAI'], dtype=object),
#  array(['L84s', 'Mtgm'], dtype=object),
#  array(['0ufvj1SlEJJXp', '1YxyYTLbzthWO', '3vzwTT0wY25GE', '4kVnq_T26xq1p',
#         '4ylQpLr46xum2hHQ', '5u2Bxlj9ua90kqrA', '6Ajbx58', '9fipLB8rlL',
#         '9pUnzWLbztKTo', 'BuhypZs', 'CrNX', 'E1aAZ0x7vd', 'FMSzZ91zL2',
#         'I6KzrtUCei', 'Ie_5MZs', 'JBfYVit4g8', 'MeOIHRG3F9', 'NhsEn4L',
#         'NjlyLMM', 'PWD40mS', 'QsQAxv5', 'TVE1uh4F_wOi_', 'TW8UhnX',
#         'UbxQ8lZ', 'WsRVNrF85oPU_', 'XfqtO3UdzaXh_', '_5OXC8MSLt',
#         'a3CcPDe', 'cOJGGr4F_wga1', 'dGiN9qj1jEYX9', 'fSKKIQdIPDXgw',
#         'fnfcPDe', 'h0lfDKh52u4GP', 'hFuvTXnQzBljb', 'iwn6', 'leSl',
#         'nlbpV6E', 'oOT00mkwDoEFW'], dtype=object),
#  array(['11p4mKe', '11pG9ir', '11pJPFL', '11pMFCG', '11pMkO_', '11pSf3Y',
#         '11pm6dL', '7N7iRy5', '7Ww3FSW', '7Ww61kb', '7Ww66JZ', '7WwCtIM',
#         '7WwEvd5', '7WwM33k', '7WwOAni', '7WwRlzF', '7WwX8Ya', '7Ww_Xqy',
#         '7WwgClh', '7WwoY2y', '7WwtEtr', '7WwuNea', '7Wwvby0', '7WwwAA_',
#         '7Wwz9n7', 'AuSBTw7', 'AuSDRR8', 'AuSPDRg', 'CWN3qSG', 'CWNBi3w',
#         'CWNY2py', 'CWNdri0', 'CWNvjgG', 'EknXpba', 'EknepHi', 'IoI4mKe',
#         'IoIkyHo', 'LxWMK5e', 'LxWMvcL', 'LxWhDOK', 'NGZFB5L', 'NGZMmo2',
#         'NGZPqH0', 'NGZXJ7z', 'NGZXfGp', 'NGZ_12K', 'NGZ_CaA', 'NGZf5u4',
#         'NGZkjXV', 'NGZokw4', 'NGZwKda', 'NGZxnJM', 'OFq55nd', 'OFq9NeO',
#         'OFqDxVQ', 'OFqDzou', 'OFqVH0t', 'OFqdri0', 'OFqmdNV', 'OFqvjgG',
#         'ORM0Mzs', 'ORMRote', 'ORMYgRH', 'ORMqC5o', 'TDc4Td_', 'TDc92TK',
#         'TDcBmwK', 'TDcECyH', 'TDcEYQ6', 'TDc_9Yi', 'TDceha3', 'TDcg1OS',
#         'TDcq2tw', 'TDctq2l', 'TDcwKda', 'X1B5ceq', 'XTb10lF', 'XTb4AFX',
#         'XTbIGOn', 'XTbIt4R', 'XTbPUYD', 'XTbQpf0', 'XTbWMnx', 'XTbj5PX',
#         'XTbjhEX', 'XTbqizz', 'XTbyntP', '_Jd5pUp', '_JdH8mF', '_JdcICD',
#         '_JdjUtW', '_JdyMnS', 'beK4AFX', 'beKAhVm', 'beKMbmK', 'beKPUYD',
#         'beKrZ3Z', 'cUQ3StG', 'cUQ4ya6', 'cUQBdwI', 'cUQBu6y', 'cUQECyH',
#         'cUQTMG1', 'cUQZTTg', 'cUQsmDD', 'jaw7f1S', 'jawB6UP', 'jawO7iH',
#         'jawXxsX', 'jawspbU', 'jawtVhC', 'kZJ7osE', 'kZJDcQU', 'kZJUo2m',
#         'kZJXxsX', 'kZJg6P6', 'kZJimtB', 'kZJs2nh', 'kZJtVhC', 'kZJyVg2',
#         'kq05rcx', 'kq067VR', 'kq0IHVu', 'kq0IYu6', 'kq0Q9BA', 'kq0RpJL',
#         'kq0XiNd', 'kq0YABQ', 'kq0YiLR', 'kq0aHkC', 'kq0dQfu', 'kq0hLo5',
#         'kq0l43t', 'kq0n8Bj', 'kq0ncmx', 'kq0pfxt', 'mAj3FSW', 'mAj8Go2',
#         'mAjAVZm', 'mAjDcoz', 'mAjIhQy', 'mAjR0Ac', 'mAjUqvc', 'mAjYZ4g',
#         'mAja5EA', 'mAjbQbU', 'mAjbk_S', 'mAjbq_f', 'mAjcfkM', 'mAjdzWk',
#         'mAjj1AH', 'mAjk2hr', 'mAjrvuI', 'mAjtFPx', 'mAjvby0', 'mAjygUE',
#         'pMW9Htj', 'pMWAe2U', 'pMWQVqj', 'pMWWkqO', 'pMWiZoa', 'pMWt2Jw',
#         'teA09W3', 'teAAXMy', 'teAAe2o', 'teAHwXo', 'teAY_NX', 'teAfWtZ',
#         'teAjUwW', 'teAyFc5', 'uZL60aU', 'uZLAN5C', 'uZLM33k', 'uZLMgHb',
#         'uZLQ8n6', 'uZLUo2m', 'uZLbQXZ', 'uZLj9VB', 'uZLuDix', 'uZLz8Sc',
#         'y5F4t8Z', 'y5F4u4t', 'y5F5CPz', 'y5FCfxT', 'y5FEvJ5', 'y5FS9RD',
#         'y5FU_7t', 'y5FewfI', 'y5FgxE9', 'y5FwXXp'], dtype=object),
#  array(['07m8iqZ', '07mmflk', '0AJo2f2', '0MQoGGc', '0bjfql_', '0vKvEWW',
#         '13j7k0_', '1FARoKG', '1Fq88FJ', '1YVRx5o', '1YVfGrO', '1hf8iqZ',
#         '1iADFjT', '1nA68SY', '1vNmS85', '25cNqhB', '2DULFbQ', '2Lw6pd1',
#         '2LwQLfu', '2WbYjZW', '380vbB7', '3JmRJnY', '3Prm94s', '3s4OZ4E',
#         '3vmv1FD', '42UoGGc', '42Uv66D', '4UxGlow', '5LLYjZW', '68RtJ9p',
#         '68RvOIl', '6JW488r', '6VLfFel', '6VLwCWN', '6g5Ojel', '6nl_w6z',
#         '7CP8jNM', '7CPRCiV', '7DID5lR', '7GEv4zN', '7OmVzos', '82JfrxM',
#         '8EdTbnP', '8GK0Q3K', '8GKOjel', '8OZoOXS', '8QvaigX', '8_r18fN',
#         '8_rYWu3', '8c868SY', '8c8KEbL', '8huQkmp', '9F7m0jM', '9Z9aXig',
#         '9qlYlW4', 'A7VR98m', 'ACmTklq', 'ALC68SY', 'ALJYlW4', 'Af96s0w',
#         'AvcOVQC', 'AxANqhB', 'BV9YlW4', 'CJTY_02', 'CjQAfvB', 'DiRY_02',
#         'Dndv4zN', 'Dw7YjZW', 'EAnsTJ7', 'EFkfR8o', 'EFki84d', 'EMvfBbO',
#         'EN4vOIl', 'EPIVHK6', 'EPImS85', 'EPIzih5', 'Ehlm94s', 'EpcahzR',
#         'ErGY_02', 'ErGovo7', 'FM28hdx', 'FMZYH7D', 'FgkYlW4', 'Fon9xXh',
#         'Fpzfql_', 'Gpv8hdx', 'Hlo8hdx', 'Hrl6pd1', 'IhOTKvt', 'Ik20nTz',
#         'Ik2OhQy', 'J8ToGGc', 'JFM1BiF', 'JO03372', 'JO06w_1', 'JO0WZR6',
#         'Jgw4fIi', 'Jt8KUco', 'K9B4K41', 'K9Bfc8E', 'KA3R98m', 'KPawGyt',
#         'KVX8iqZ', 'KbkKEj0', 'KhWfR8o', 'KhlYWu3', 'KjR3372', 'KjR6w_1',
#         'KnzzTww', 'L91KIiz', 'L91lh_I', 'LWkYE38', 'LWnfSEp', 'Lu8se7s',
#         'LwGCME0', 'LwGVino', 'LwGmro4', 'ME5YWu3', 'MMTJrCp', 'MPav4zN',
#         'MgW0FxM', 'MiS0IU9', 'MiSOw16', 'NI568SY', 'NI5gmOy', 'NRwYlW4',
#         'Nzc87dl', 'O30mFX7', 'O3eR2zc', 'OTgQ8OA', 'OTgfc8E', 'OTguLpj',
#         'OVz6pd1', 'OXxlI5k', 'OYHAk0_', 'OYHOVQC', 'OYHoGfM', 'Oa96V3V',
#         'OgVfql_', 'Oj6fql_', 'OjIAe72', 'OjIYE38', 'OrnLfvc', 'Ox8fR8o',
#         'P2HDiZ1', 'PCSKsQe', 'PqGY_02', 'QMaRwBA', 'Qf2oI0_', 'Qkc66eq',
#         'QkcCjOi', 'QkcOZ4E', 'Qkc_DXg', 'Qui18fN', 'R4hRoKG', 'R4hm94s',
#         'R8kKx11', 'ROefGrO', 'ROeipLp', 'RnYsGWp', 'SCnAQQR', 'SCnYWu3',
#         'SwO3uEC', 'T6w0nTz', 'T6wOhQy', 'TE7NqhB', 'THM88FJ', 'THMVGQ9',
#         'TIB8hdx', 'TLbNioI', 'TPHfrxM', 'TVjYWu3', 'Tvpip6Z', 'U3CYjZW',
#         'U8IKsQe', 'U8IVcJ1', 'UF16siJ', 'UISY_02', 'URPcqVw', 'UbxT9Uy',
#         'UiC6V3V', 'UsFCnO3', 'UvLOVQC', 'UvL_w6z', 'V8hvOIl', 'VA_88FJ',
#         'VA_m0jM', 'VDdNioI', 'VgKv48t', 'VsU68SY', 'WEga9N8', 'WPf93Yc',
#         'WTK88FJ', 'WWmfR8o', 'WZA8iqZ', 'WaovEWW', 'WdP1WU5', 'XVim94s',
#         'XbZfrxM', 'XbZitea', 'Xei0nTz', 'XeiNqhB', 'XsN0un2', 'XsNOZ4E',
#         'Xsg8XLE', 'Xsgmfvd', 'Y578iqZ', 'YBh0nTz', 'YBhNqhB', 'YTCRPlm',
#         'YZ2FaW0', 'YZ2TNgw', 'Z6VR15G', 'Z6VfSEp', 'Z6VzNJS', 'ZDjvbB7',
#         'ZLOD5lR', 'ZLOfc8E', 'ZLOpNvz', 'ZN38Wb4', 'ZN3fSEp', 'ZS80FxM',
#         'ZV0mFX7', 'Zcz6V3V', 'Zno88FJ', 'ZoXfR8o', '_Mc87dl', '_McRoKG',
#         '_PxA1m8', '_am1sjm', '_amvbB7', '_oSvdH_', '_vdOjel', 'aD1vOIl',
#         'aL0D5lR', 'aL0uLpj', 'aRuY_02', 'aTW8jNM', 'aau0ETb', 'aau1rOn',
#         'agOwCWN', 'aldAAox', 'b0vOZ4E', 'bDIfGrO', 'bDf87dl', 'bDfR2zc',
#         'bZhDGHt', 'cABfGrO', 'cXse4eD', 'cfcfc8E', 'ch2oGfM', 'dMzYH7D',
#         'dNs0Q3K', 'dZDAHgk', 'dbpfR8o', 'do06V3V', 'dqL8hdx', 'dukR15G',
#         'e2D1a9D', 'e2DHmNo', 'e8BBfYU', 'eJsfrxM', 'eNCmIK9', 'eTk1UQz',
#         'efg0Kix', 'efgVzos', 'ezqvEWW', 'fOgDSPW', 'fabDFjT', 'fabLnWA',
#         'fabfGrO', 'fgzRJnY', 'fxJ68SY', 'fxJmel6', 'gbo1rOn', 'gfM8XLE',
#         'gfMRJnY', 'gg7ovo7', 'gwj3_5u', 'h724_jR', 'h72fSEp', 'hAX6pd1',
#         'hFpkN94', 'i9JuX8Z', 'iEX0Q3K', 'iEXADXQ', 'iEXNN3u', 'iEXOjel',
#         'iVsfql_', 'iokiSQE', 'jE90Azj', 'jE9OVQC', 'k5O88FJ', 'kC8vOIl',
#         'kH5C5vH', 'kH5RngW', 'kH5mFX7', 'kH5sgTz', 'kTkv10k', 'kogfGrO',
#         'lK7idD8', 'lQQ9Ncd', 'lRbzNJS', 'lbrVHK6', 'mTDfR8o', 'mTP8jNM',
#         'mXL38SL', 'mXL6hzI', 'meWVy8V', 'meWmFX7', 'nf9OhQy', 'oatipLp',
#         'ot6oLzk', 'p40KIAf', 'pHXA5lA', 'pHXYlW4', 'pIAmJge', 'pqU6hzI',
#         'q3qz4KI', 'qofOVQC', 'r5hYlW4', 'rLf8iqZ', 'rulfc8E', 's3vse7s',
#         'sTyQFhp', 'scZ0Q3K', 'scZOjel', 'sd2OZ4E', 'srGv1FD', 'stpDZvv',
#         'stpv4zN', 'sx5ARL_', 'sx5YWu3', 'sy79Ncd', 't0rm0jM', 't39_HBW',
#         't5EoLzk', 't5EvdH_', 'tCbv48t', 'tCbv66D', 'tS19OJS', 'tZkYuYC',
#         'taaOZ4E', 'tjWYlW4', 'u9OfrxM', 'uIoKu_a', 'uUY0Q3K', 'uUYunG_',
#         'um1fql_', 'uwLfql_', 'uwhY_02', 'uyr88FJ', 'vM86s0w', 'vM89sBz',
#         'vU6NT4W', 'vcuv48t', 'vjPo2f2', 'vjPtxWD', 'vtCOZ4E', 'vz9fSEp',
#         'wIfOw16', 'wUQOw16', 'wZZm94s', 'wvSrYcf', 'x6SiFZ_', 'xDj6pd1',
#         'xKnYH7D', 'xlbvdH_', 'xtRTKvt', 'yAL1OQN', 'yBu8hdx', 'yBuQKBt',
#         'yMCvEWW', 'yNF0Azj', 'yNFOVQC', 'ylC6pd1', 'ylCK4WV', 'ys1oLzk',
#         'zJh68SY', 'zqsvdH_'], dtype=object),
#  array(['Al6ZaUT', 'JIiEFBU', 'QKW8DRm', 'd0EEeJi', 'oslk', 'z4pH', 'zCkv'],
#        dtype=object),
#  array(['017QQMs', '05j67Xw', '09qA9vx', '0D0gQ7h', '0JeRt72', '0MpQv5o',
#         '0VTT3Cb', '1E9D3Yd', '1J2cvxe', '1OjDLrQ', '1bwwFs9', '1gu2qo0',
#         '24OHEwz', '2Kb5FSF', '2fF2Oqu', '3A8Rt2K', '3z2QQMs', '43LcanV',
#         '460km3N', '4IrA9vx', '4JiE4Qn', '4sF7qqc', '4wZOTZB', '5037lZj',
#         '503RDbC', '503jKAP', '51wlOzR', '5Doz_Kt', '5YyyovK', '6JshouF',
#         '6YSVTM2', '6ZOocsg', '6ebzrB7', '6zMjbRT', '76DJixu', '77v2c2r',
#         '7CnSoTa', '7_Nj7qz', '82XQQMs', '83UEsaq', '853QZmh', '853aRTx',
#         '8ag7A2G', '8dbQowC', '8erPsJz', '8oT2fT4', '8xSqDjb', '99nURQu',
#         '9JvQQMs', '9kj7A2G', 'A5pE4Qn', 'AEKwFs9', 'APUE4Qn', 'APgdzOv',
#         'APgu8Zv', 'AT9E4Qn', 'AmO2pc5', 'B1BED8N', 'BG5Rt2K', 'BNrD3Yd',
#         'BT6Rt2K', 'BULTE6Y', 'BXGzrB7', 'BeDRkup', 'Bfv7kpB', 'C6OGkwT',
#         'CE7uk3u', 'CTlKvPi', 'CW6RDbC', 'CWizrB7', 'CmhRjAG', 'CnZoIp0',
#         'CqZ4IB0', 'CqZz20V', 'D3U6s6Y', 'D3UitGv', 'D7cED8N', 'DGsqhZX',
#         'DHPNgqU', 'DNvRusu', 'DQ3iZDY', 'DQ3u3MC', 'DUSBCX3', 'DkXDnag',
#         'DrA79_c', 'E2dQguc', 'EPqQcw6', 'EROH7Cg', 'EbgaySi', 'EmeSanL',
#         'Exf7DIf', 'F2mOEra', 'F7_Bj8v', 'FYyQowC', 'FlORusu', 'FlVqhZX',
#         'FnxQQMs', 'GSZEVJ2', 'GeD7j0h', 'H2gyovK', 'H9aOEra', 'HMhOTZB',
#         'HX39lNX', 'HcpEsaq', 'HiG2C8o', 'I6H64xm', 'IBLXWyT', 'IDn52bd',
#         'IEQTy9x', 'IIvC99a', 'IIvQguc', 'IKPOtEt', 'IWyDN1n', 'IhKskzO',
#         'IrZED8N', 'JIB9h3w', 'J_tzF_Q', 'JaZwBif', 'JcMjELi', 'JtcUsvC',
#         'K2SqEo9', 'KBgRDbC', 'KOqA9vx', 'KZOytFJ', 'KcC08Cl', 'KrlSanL',
#         'L8yRgaQ', 'L8ywwUI', 'LPD2Oqu', 'LsfEVaf', 'MHP7DIf', 'MI8iYHE',
#         'MI8s5nE', 'MM1zrB7', 'MRPKMwm', 'MU1qI2t', 'MkQldxq', 'MmHzF_Q',
#         'MnYAKIt', 'N0GYONy', 'N8wTzYj', 'NKv4yOc', 'NNyRUH6', 'NWMQQMs',
#         'NbpRb9q', 'NnYzgmc', 'OBtaI_R', 'OTXAgOW', 'OgxHixs', 'Oh06Kfh',
#         'OjiRt72', 'OvO2c2r', 'OvOQls0', 'P6mQZmh', 'P6pu4Vl', 'PNQIwLq',
#         'PQROEra', 'PXpQv5o', 'PgO2Oqu', 'Pml6FsY', 'QIhOTZB', 'QKXEsaq',
#         'QfJz_Kt', 'QhgRt72', 'QkgQQMs', 'QpZO8fW', 'QqVuch3', 'R2LdzOv',
#         'R9o52Lp', 'RVQiZDY', 'Rkj9jvX', 'RlTRt72', 'RlTh9x_', 'RsCQLlz',
#         'S2JrUdI', 'SQ6ghm3', 'SqzQZmh', 'SwpRogq', 'SyxQQMs', 'T5HWwhx',
#         'T63AwsZ', 'TT_zF_Q', 'TUP6P29', 'TYFQguc', 'TZoq6Bf', 'T_gzrB7',
#         'UQenOT8', 'UQs7kpB', 'UbjqFbB', 'UzTsfxE', 'VNjXcTb', 'VQZzrB7',
#         'VTxynIC', 'VWtIBQt', 'VjJ1V_1', 'VjJAgOW', 'Vo68gbh', 'VpmCBom',
#         'VyMCL5c', 'W41oG9v', 'WC7Esaq', 'WC7IXkw', 'WUmK0JH', 'WfsWw2A',
#         'WmdTQlu', 'X7rObSS', 'X9a41Yn', 'XByOEra', 'XHOAGfT', 'XKaTy9x',
#         'XQvKSaP', 'XdAUmxB', 'XlgxB9z', 'YE7zrB7', 'YFnaXbj', 'YKu7j0h',
#         'Z16AAUb', 'ZdsRt72', 'ZpR4e0W', 'ZwrQhib', 'ZwrmOr3', '_BMKSUK',
#         '_XS7lZj', '_rKAGfT', '_sz_44J', '_wyAgOW', 'a4o7nDv', 'a4oQQMs',
#         'ag5iNPX', 'alU2fT4', 'au82_Lp', 'b0i9fPb', 'b5YgyXK', 'b6TozkN',
#         'bIKqCcD', 'bIUTy9x', 'bMSObSS', 'bcU6icy', 'boJxCPk', 'c1HOTZB',
#         'c4R2fT4', 'c78T3Cb', 'cObOJ79', 'cWNRt2K', 'catzS2D', 'cbq7j0h',
#         'cpKwiqw', 'cwU7qqc', 'dEJz4Af', 'dOHQowC', 'dc9c_aX', 'dclYaaM',
#         'dh6qI2t', 'dxUMkpY', 'dzQRt72', 'e333Hum', 'e7bTQlu', 'eIi2qo0',
#         'emgCF4K', 'ep2j7qz', 'erEqhZX', 'f1AO_7b', 'f76ryQi', 'fV_z4Af',
#         'fXVEsaq', 'fXVIXkw', 'frAh5QF', 'fs3coch', 'g2NpVAO', 'g57nG2q',
#         'ghXQowC', 'gpUKvPi', 'gv2w01M', 'gwFnQez', 'hFzRusu', 'hHJsvbM',
#         'hYsWQhn', 'huSt_DD', 'iHXRkup', 'iPWgyXK', 'iQJ2C8o', 'j32r3XO',
#         'jCiQv5o', 'jG3QowC', 'jhrTQlu', 'jm4UDU9', 'jpmOtEt', 'jrbDSFl',
#         'kEYAGfT', 'kPWQhib', 'kWFEVJ2', 'kYwEsaq', 'kiBRltV', 'knDz20V',
#         'l9eMpgG', 'lAlqYia', 'lJxNMua', 'lv86Kfh', 'mAtHCkC', 'mErwEWL',
#         'mWoTy9x', 'mehDnag', 'mfC2Oqu', 'mhe7j0h', 'nKcTL5Q', 'nRgz4Af',
#         'nXK9h3w', 'nXOQZmh', 'nuwugiB', 'nuwzgmc', 'nx1K0JH', 'nyX2C8o',
#         'nytT3Cb', 'o9Y6TM2', 'oCqTy9x', 'oCzEVaf', 'oKEqhZX', 'oSyMpgG',
#         'p2sz20V', 'pDZryQi', 'pWu6FsY', 'pfURltV', 'pm_TE6Y', 'qDl2pc5',
#         'qWj5Ui8', 'qjNw0n7', 'r1y7DIf', 'r757j0h', 'rDbG_aX', 'rT1Esaq',
#         'rUj52Lp', 'renAIRG', 'rnqMak1', 'rvbsTKW', 's4wQZmh', 'sd7w991',
#         'spyTQlu', 'tBKqqb8', 'tByjPJU', 'tzhGkwT', 'u4HRusu', 'u4_Rusu',
#         'uBYMak1', 'uClRusu', 'uVOtSzd', 'uYhbyK7', 'ua1YaaM', 'unpQ3DB',
#         'uyDQguc', 'v5hz20V', 'v8MoT7F', 'vUcOEra', 'vvSRt2K', 'wWBXf37',
#         'wYv2Oqu', 'wYvXbDK', 'wniqI2t', 'wzps5nE', 'x3aOgRj', 'xKMwIB5',
#         'xMusxs4', 'xNaD3Yd', 'xTFQowC', 'xWWynIC', 'xYH_Q4n', 'xhoMnus',
#         'xmA7A2G', 'xmAuVKu', 'y1zz20V', 'y9NqhZX', 'ygD7j0h', 'yktAIRG',
#         'z9uOG09', 'zFwT3Cb', 'zUldlhv', 'zbRHEwz', 'zccfeJ_', 'zmvzrB7',
#         'zqP3NNv', 'zwFAGfT'], dtype=object),
#  array(['3Cy4', '453m', '5Acm', '7FJQ', '7P5s', '7aLG', 'Aoh3', 'FSa2',
#         'PM2D', 'Qcbd', 'Qu4f', 'TNEC', 'WqMG', 'Xa3G', 'fKCe', 'kwS7',
#         'me1d', 'rgKb', 'szEZ', 'uWr3', 'wX53', 'w_Ub', 'xb3V'],
#        dtype=object),
#  array(['02N6s8f', '6fzt', 'RAYp', 'ZI9m', 'nIGXDli', 'vJ_w8kB'],
#        dtype=object),
#  array(['0pzBWGkV3fbsGZN52DH', '55YFVY9', 'F2FcTt7IdMT_v', 'F2FyR07IdsN7I',
#         'JnGLH58smNxIYcGK39k', 'NoEd', 'R4y5gQQWY8OodqDV',
#         'SbOd7O8ky1wGNxp0Arj0Xs', 'TCU50_Yjmm6GIBZ0lL_', 'VjDE',
#         'WfJ2BB2SFSqauljlfOB', 'WfJYmPMksSqa1pajvfG', 'ZeaF', 'Zy3gnGM',
#         'am14IcfM7tWLrUmRT52KtA', 'ib5G6X1eUxUn6', 'iyHGyLCEkQ',
#         'xwM2aC7IdeMC0'], dtype=object)]

# %% [markdown]
# ## Model Creation

# %%
bike.drop('datetime',axis=1,inplace=True)

# %%
bike.head()
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  windspeed  \
# 0       1        0           0        1  9.84  14.395        81        0.0
# 1       1        0           0        1  9.02  13.635        80        0.0
# 2       1        0           0        1  9.02  13.635        80        0.0
# 3       1        0           0        1  9.84  14.395        75        0.0
# 4       1        0           0        1  9.84  14.395        75        0.0
#
#    casual  registered  count
# 0       3          13     16
# 1       8          32     40
# 2       5          27     32
# 3       3          10     13
# 4       0           1      1

# %%
from sklearn.model_selection import train_test_split

X=bike.drop('count',axis=1).values
y=bike['count']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-623d859df91b> in <module>()
#       1 from sklearn.model_selection import train_test_split
#       2
# ----> 3 X=bike.drop('count',axis=1).values
#       4 y=bike['count']
#       5
#
# NameError: name 'bike' is not defined

# %%
from sklearn.ensemble import RandomForestRegressor

rf=RandomForestRegressor()
rf.fit(X_train,y_train)
# Out:
# D:\ARUl\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
rf.feature_importances_
# Out:
# array([2.67142929e-05, 2.64846970e-06, 1.55510302e-04, 2.81303598e-05,
#        9.89316759e-05, 5.91701907e-05, 9.84868125e-05, 7.75545874e-05,
#        5.09013535e-02, 9.48551500e-01])

# %%
rf.predict(X_test)
# Out:
# array([128.4,  13. , 162. , ..., 294.6, 464.1, 385.4])

# %%
predictions=rf.predict(X_test)
predComp=pd.DataFrame({'Predictions':predictions,'Actual':y_test})
predComp.head()
# Out:
#       Actual  Predictions
# 3133     127        128.4
# 5786      13         13.0
# 5224     163        162.0
# 8953     233        234.9
# 8054     222        223.1

# %%
a4_dims = (20, 10)
fig, ax = pyplot.subplots(figsize=a4_dims)

sns.lineplot(ax=ax,data=predComp[:100],palette='tab10')

# %%
predComp.to_csv("finalPred.csv")

# %%
prediction
